# %% [markdown]
# <a href="https://colab.research.google.com/github/dinael2000/archaeo_mde_to_3D/blob/main/run_pipeline/full_workflow_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🤖 Leveraging Monocular Depth Estimation for the rapid 3D Digitization of Cultural Heritage Artefacts 🤖
#
# ## 💻 Full MDE-to-3D Pipeline
#
# The following Notebook provides a full pipeline for the production of 3D models of coin-like objects, starting from a single image as input.
#
# It is being developed as part of an ongoing Master Thesis on:
# "Utilizing Monocular Depth Estimation (MDE) Models for the Digitization of Cultural Heritage Objects. Leveraging deep learning-based MDE-Algorithms for the production of 3D models of archaeological artefacts that carry micro-reliefs.", carried out at the Universität zu Köln.
#
# Make sure to go through all cells sequentially. Click the start button (▶) next to each one to get it to work. Carefully read the instructions before each step, it will help save you a lot of time!
#
# ⏱️ Is added when a task is expected to last up to a few minutes.

# %% [markdown]
# ## ❗The current pipeline was designed to run on Python 3.12. As of 08/2026, Google Colab has upgraded to Python 3.13, which renders certain utilized libraries incompatible with the current implementation. In order to run the pipeline properly, please change to an older runtime, as shown below (Section 1.1.2.) ❗

# %% [markdown]
# ### 1. Setting up the environment

# %% [markdown]
# ⏱️ This step will take a few minutes (c. 4 mins), so don't stress it 😊
#
# ❗When prompted to, click on **Restart Session** and continue to the next cell ❗
#
# After it is finished, you may click on the downwards pointing arrowhead to collapse the output table.

# %%
# %%capture
# 1.1. Clone github repository
# !git clone https://github.com/dinael2000/archaeo_mde_to_3d.git

# %%
# 1.1.2. Set up Google Colab Runtime (follow instructions)
import cv2

from google.colab.patches import cv2_imshow

# %cd /content/archaeo_mde_to_3d/assets/Colab_Setup/

step_1 = cv2.imread('Step_1.png')
cv2_imshow(step_1)
step_2 = cv2.imread('Step_2.png')
cv2_imshow(step_2)
step_1 = cv2.imread('Step_3.png')
cv2_imshow(step_3)
step_1 = cv2.imread('Step_4.png')
cv2_imshow(step_4)
# Out:
# /content/archaeo_mde_to_3d/assets/Colab_Setup
# <PIL.Image.Image image mode=RGB size=1920x1200>
# <PIL.Image.Image image mode=RGB size=1920x1128>
# <PIL.Image.Image image mode=RGB size=1920x1128>
# <PIL.Image.Image image mode=RGB size=1920x1128>

# %%
# %cd /content/archaeo_mde_to_3d

# !pip install -r requirements.txt

# Click on the downwards pointing arrowhead to collapse the output table

# %%
# 1.2.2. Re-run after restarting session
# %%capture
# !pip install -r requirements.txt
# !pip install open3d

# %%
# 1.3. Initiate libraries
# %%capture
import os

# %%
# 1.4. Read project modules
# %%capture
# %cd /content/archaeo_mde_to_3d/run_pipeline

from depthanythingv1_function import *
from no_cropping import *
from openback import *
from watertight import *
from merge_meshes import *
from scale_meshes import *
from utils_colors import *
from utils_pointcloud import *
from visualize_mesh import *

# %% [markdown]
# ### 2. Set up depth estimation pipeline

# %%
# 2.1. Initiate directories

# Directory with input images
rgb_dir = "rgb_dir"
os.makedirs(rgb_dir, exist_ok=True)

# Directory to save .npy depth maps
depth_npy_dir = "depth_npy_dir"
os.makedirs(depth_npy_dir, exist_ok=True)

# Directory to save colored depth maps
depth_colored_dir = "depth_colored_dir"
os.makedirs(depth_colored_dir, exist_ok=True)

# Directory to save black-and-white depth maps
depth_bw_dir = "depth_bw_dir"
os.makedirs(depth_bw_dir, exist_ok=True)

# 2.2. Choose colormap-scheme for colored depth map

# %%
color_scheme = "inferno" # @param ["inferno","viridis","plasma","magma","cividis"] {"allow-input":true}

# %%
# 2.3. Test Data

# %% [markdown]
# **2.3. Option 1: Upload your own data**
#
# ⏱️ This step will take a few minutes.
#
# For quicker processing times, you may also upload the desired file(s) directly to:
# /content/MDE_to_3D/run_pipeline/rgb_dir
# (CTRL + Left Click for quick access)
#
# ❗ Important Notes ❗
#
# * Make sure that the object is mostly **centered** in the frame of the uploaded picture
# * Make sure that the object occupies a **large space** in the frame of the uploaded picture
# * Should you wish to *merge* two sides of an object (obv-rev), make sure that:
# 1. Each side occupies roughly the same space in each frame (to facilitate alignment)
# 2. Each side is named appropriately (e.g. "{object_name}-obv", "{object_name}-rev". It is *vital* that each side has the same name.

# %%
from google.colab import files

# %cd /content/archaeo_mde_to_3d/run_pipeline/rgb_dir
uploads = files.upload()

# %cd /content/archaeo_mde_to_3d/run_pipeline

# %% [markdown]
# **2.3. Option 2: Use test data**
#
# If you do not have your own dataset, you may use the photos
# provided in the test_data folder

# %%
rgb_dir = "test_data"

# %% [markdown]
# ### 3. Depth Estimation with DepthAnything V1
# Yang, L., Kang, B., Huang, Z., Xu, X., Feng, J., Zhao, H., "Depth Anything: Unleashing the Power of Large-Scale Unlabeled Data". 2024.
#
# Available at: [GitHub](https://github.com/globalwetlands/depth-anything-V1), [HuggingFace](https://huggingface.co/spaces/LiheYoung/Depth-Anything)

# %%
# 3.1. Run depth estimation pipeline

run_depth_estimation(rgb_dir=rgb_dir, depth_npy_dir=depth_npy_dir, depth_bw_dir=depth_bw_dir, depth_colored_dir=depth_colored_dir, color_scheme=color_scheme)

# %%
# 3.2. (Optional) Download depth maps
from google.colab import files
path_npy = "/content/archaeo_mde_to_3d/run_pipeline/depth_npy_dir"
path_colored = "/content/archaeo_mde_to_3d/run_pipeline/depth_colored_dir"
path_bw = "/content/archaeo_mde_to_3d/run_pipeline/depth_bw_dir"

for file in os.listdir(path_npy):
  file_path = os.path.join(path_npy, file)
  print(file_path)
  files.download(file_path)

for file in os.listdir(path_colored):
  file_path = os.path.join(path_colored, file)
  print(file_path)
  files.download(file_path)

for file in os.listdir(path_bw):
  file_path = os.path.join(path_bw, file)
  print(file_path)
  files.download(file_path)

# %% [markdown]
# ### 4. 3D model creation
#
# The following sections provide different options for creating 3D models, using the depth maps produced in the previous steps:
#
# 1. The *first* section enables the production of non-watertight models of the full scene depicted in the provided image, i.e. an uncropped mesh.
#
# 2. The *second* section enables the production of non-watertight models of a cropped section of the scene, which should correspond to the object of interest and can be used as such, or to then merge into a single model.
#
# 3. The *third* section enables the production of (mostly) watertight models, which can be used as such.
#
# 4. The *fourth* section enables merging two (non-watertight) models into a single, full object. If you wish to merge two sides of a seal into a single 3D object, you **need** to go through **Option 2** ❗❗❗
#
# 5. The *fifth* section enables scaling any given model.
#
# After each section, you may **download** the 3D models to your local system.
#
# Alternatively, you may **view** the objects in the browser, with the help of a dedicated visualizer (*Section 5*)

# %% [markdown]
# ### 4.1. Set up document-wide parameters
#
# ❗❗❗ Before starting the 3D modeling process, you **need** to set up the following parameters for the entire file.
#
# If you wish to **change** the parameters before each step, simply adjust the slider and re-run the cell. Feel free to play around with them and explore how different configurations affect the end-result.
#
# See the ***Parameter Index*** **at the end of this file** for more information. **Recommended values** are provided.

# %%
pixel_size = 1 # @param {"type":"slider","min":0.5,"max":1,"step":0.1}

# %% [markdown]
# (**Recommended Value**: 1.0)

# %%
relief_scale = 5 # @param {"type":"slider","min":0,"max":10,"step":1}

# %% [markdown]
# (**Recommended Value**: 5.0)

# %%
poisson_depth = 9 # @param {"type":"slider","min":5,"max":10,"step":1}

# %% [markdown]
# (**Recommended Value**: 9.0)

# %%
output_format = "obj" # @param ["obj","ply","glb"] {"allow-input":true}

# %% [markdown]
# (**Recommended Value**: "obj")

# %%
gap_factor = -0.5 # @param {"type":"slider","min":-1,"max":1,"step":0.1}

# %% [markdown]
# **Recommended Value**: -0.5 (Works with *most* but *not all* tested objects)

# %% [markdown]
# #### 4.2. Non-Watertight Uncropped Models

# %%
# 4.2.1 Set up directories
out_dir_uncropped = "3d_models_uncropped"
os.makedirs(out_dir_uncropped, exist_ok=True)

# %%
# 4.2.2. Run module
batch_process_no_cropping(depth_npy_dir, rgb_dir, out_dir_uncropped, output_format=output_format)

# %%
# 4.2.3. (Optional) Download created models
from google.colab import files
path = "/content/archaeo_mde_to_3d/run_pipeline/3d_models_uncropped"

for mesh in os.listdir(path):
  file_path = os.path.join(path, mesh)
  print(file_path)
  files.download(file_path)

# %% [markdown]
# #### 4.3. Non-Watertight Models

# %%
# 4.3.1. Set up directories
out_dir_openback = "3d_models_non_watertight"
os.makedirs(out_dir_openback, exist_ok=True)

# %%
# 4.3.2. Run module
batch_process_openback(depth_npy_dir, rgb_dir, out_dir_openback, output_format=output_format, pixel_size=pixel_size, relief_scale=relief_scale, poisson_depth=poisson_depth)

# %%
# 4.3.3. (Optional) Download created models
from google.colab import files

path = "/content/archaeo_mde_to_3d/run_pipeline/3d_models_non_watertight"

for mesh in os.listdir(path):
  file_path = os.path.join(path, mesh)
  print(file_path)
  files.download(file_path)

# %% [markdown]
# #### 4.4. Watertight Models
#
# ⏱️ This module takes a significant amount of time to run, due to the complexity of the task. It is recommended that you process a smaller dataset.
#
# Or grab a coffee while waiting ☕

# %%
# 4.4.1. Set up directories
out_dir_watertight = "3d_models_watertight"
os.makedirs(out_dir_watertight, exist_ok=True)

# %%
# 4.4.2. Run module
batch_process_watertight(depth_npy_dir, rgb_dir, out_dir_watertight, output_format=output_format, pixel_size=pixel_size, relief_scale=relief_scale, poisson_depth=poisson_depth)

# %%
# 4.4.3. (Optional) Download created models
from google.colab import files

path = "/content/archaeo_mde_to_3d/run_pipeline/3d_models_watertight"

for mesh in os.listdir(path):
  file_path = os.path.join(path, mesh)
  print(file_path)
  files.download(file_path)

# %% [markdown]
# #### 4.5. Merged Models

# %%
# 4.5.1. Set up directories
input_dir = "/content/archaeo_mde_to_3d/run_pipeline/3d_models_non_watertight"
output_dir_merged = "3d_models_merged"
os.makedirs(output_dir_merged, exist_ok=True)

# %%
# 4.5.2. Run module

# %% [markdown]
# ⏱️ Depending on the model geometry, the merging process could take a few minutes per model.

# %%
batch_process_merge(input_dir, output_dir_merged, output_format=output_format, gap_factor=gap_factor, scale=False, scale_factor=0)

# %%
# 4.5.3. (Optional) Download created models
from google.colab import files

path = "/content/archaeo_mde_to_3d/run_pipeline/3d_models_merged"

for mesh in os.listdir(path):
  file_path = os.path.join(path, mesh)
  print(file_path)
  files.download(file_path)

# %% [markdown]
# #### 4.6. Scaled Models
#
# Choose a folder to scale the created meshes from.

# %%
# 4.6.1. Set up directories

# %%
input_dir_to_scale = "/content/archaeo_mde_to_3d/run_pipeline/3d_models_uncropped" # @param ["/content/archaeo_mde_to_3d/run_pipeline/3d_models_non_watertight","/content/archaeo_mde_to_3d/run_pipeline/3d_models_watertight","/content/archaeo_mde_to_3d/run_pipeline/3d_models_merged","/content/archaeo_mde_to_3d/run_pipeline/3d_models_uncropped"]

# %%
output_dir_scaled = "3d_models_scaled"
os.makedirs(output_dir_scaled, exist_ok=True)

# %%
# 4.6.2. Set up scale factor

# %%
scale_factor = 0.2 # @param {"type":"slider","min":0,"max":1,"step":0.01}

# %%
# 4.6.3. Run module
batch_scale_models(input_dir_to_scale, output_dir_scaled, scale_factor=scale_factor)

# %%
# 4.6.4. (Optional) Download created models
from google.colab import files
path = "/content/archaeo_mde_to_3d/run_pipeline/3d_models_scaled"

for mesh in os.listdir(path):
  file_path = os.path.join(path, mesh)
  print(file_path)
  files.download(file_path)

# %% [markdown]
# ### 5. Visualize meshes
#
# Choose a folder to visualize the created meshes from.

# %%
# 5.1. Initiate libraries
import plotly.graph_objects as go
import numpy as np
import open3d as o3d

# 5.2. Select folder to visualize meshes from

# %%
mesh_folder = "/content/archaeo_mde_to_3d/run_pipeline/3d_models_non_watertight" # @param ["/content/archaeo_mde_to_3d/run_pipeline/3d_models_non_watertight","/content/archaeo_mde_to_3d/run_pipeline/3d_models_watertight","/content/archaeo_mde_to_3d/run_pipeline/3d_models_merged","/content/archaeo_mde_to_3d/run_pipeline/3d_models_scaled","/content/archaeo_mde_to_3d/run_pipeline/3d_models_uncropped"]

# %%
# 5.3. Visualize Meshes
batch_visualize_meshes(mesh_folder)

# %% [markdown]
# #### ❗ Parameter Index ❗:
# ##### Setting up parameters
# In order to run the 3D-model generation modules, certain parameters have to be set up. These are the following:
# 1. *pixel_size*:
#
# Pixel Size controls the XY spacing between neighboring depth samples, setting the real-world scale per pixel in the X and Y directions. This parameter affects the overall size of the reconstructed object, *without* affecting shape.
#
# A **smaller** pixel_size value shrinks the object in XY, permitting higher detail density. A **larger** pixel_size value increases the object in XY, making the surface less detailed.
#
# **Recommended Range**: 0.5-1.0
#
# **Recommended Value**: 1.0
#
# 2. *relief_scale*
#
# Relief Scale controls depth variation (Z) relative to X and Y. By scaling the object surface, it accounts for the low dynamic range present in MDE-created depth maps.
#
# A **smaller** relief_scale smoothens surface-details on the object. A **larger** relief_scale exaggerates surface-details on the object.
#
# **Recommended Range**: 5.0-9.0
#
# **Recommended Value**: 8.0
#
# 3. *poisson_depth*
#
# Poisson Octree Depth controls the model's resolution, by setting the max subdivision level for the reconstruction triangle count and surface detail.
#
# A **smaller** poisson_depth results in a coarser model, but requires less computation time. A **larger** poisson_depth results in a more detailed model, but requires more computation time. A **very large** poisson_depth may result in a lot of unecessary noise.
#
# **Recommended Range**: 7-10
#
# **Recommended Value**: 8 or 9
#
# 4. *output_format*
#
# Output format controls the file-type for the generated 3D model.
#
# **Recommended Options**: "obj", "ply", "glb"
#
# **Recommended Value**: "obj"
#
# 5. *gap_factor*
#
# Gap factor controls the gap in the Z axis that will be allowed between each aligned side of the model-to-be-merged.
#
# A **smaller** gap_factor brings the two sides closer together, but may result in conflicting geometry. A **larger** gap_factor seperates the two sides further, but may result in gaps in the mesh. Requires trial-and-error, can be decided on a case-by-case scenario.
#
# **Recommended Range**: -0.5-1.0
#
# **Recommended Value**: -0.5 (Works with *most* but *not all* tested objects)
#
# 6. *scale_factor*
#
# Scale factor controls the value by which the object will be scaled.
